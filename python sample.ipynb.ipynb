# %%
print("**********Basic Python Programming*************")

print("this is a commented line in Python")
# this is a commented line in Python
'''This is a
     multiline
     comment.'''

#Python treats single quotes the same as double quotes.
print("Python treats single quotes the same as double quotes.")
x='Inceptez '
y="'Technologies'"
z="Pvt.\tLtd."
print("welcome " + x + y+z)
greet="Welcome to " \
      "Python" \
      "learning "
greet1="""Welcome to 
Pyspark 
learning """

print(greet)
print(greet1)

print("Data Types and characteristics")
flt=10.23
print("The type of variable having value", flt, " is ", type(flt))
isins=isinstance(flt,float)
print(isins)

#strings are immutable
tmpstr = "Test"
print(tmpstr[0])
#tmpstr[2]='r'

print ("strings are immutable" + tmpstr)

print("String & Num operations")
strdata = "this IS test data"

print("Convert to Upper Case:",strdata.upper())
print("Check upper:",strdata.isupper())
print("Convert to lower Case:",strdata.lower())
print("Check lower:",strdata.islower())
print("Check numeric:",strdata.isnumeric())
print("get no of occurances:",strdata.count("i"))
print("Starts with :",strdata.startswith("t"))
print("Ends with :",strdata.endswith("a"))

#len() function returns the length of the object. This function internally calls __len__() function of the object. So we can use len() function with any object that defines __len__() function.
print("Length of the sequence " + str(len(strdata)))

num1=100
num2=200
print(num1+num2)

print('Dynamic Inference and Dynamic typed')
num1=100
num2=200
print(num1)
print(isinstance(num1,int)) #If its true then Dynamic inference
num3=num1 + num2
print(num3)
num1="Inceptez" #dynamically typed
print(num1.isnumeric())
print(num1)
print(type(num1))
print('Strongly typed')
num3=num1 + num2 #strongly typed
print(num3)
# Out:
# **********Basic Python Programming*************
# this is a commented line in Python
# Python treats single quotes the same as double quotes.
# welcome Inceptez 'Technologies'Pvt.	Ltd.
# Welcome to Pythonlearning
# Welcome to
# Pyspark
# learning
# Data Types and characteristics
# The type of variable having value 10.23  is  <class 'float'>
# True
# T
# strings are immutableTest
# String & Num operations
# Convert to Upper Case: THIS IS TEST DATA
# Check upper: False
# Convert to lower Case: this is test data
# Check lower: False
# Check numeric: False
# get no of occurances: 1
# Starts with : True
# Ends with : True
# Length of the sequence 17
# 300
# Dynamic Inference and Dynamic typed
# 100
# True
# 300
# False
# Inceptez
# <class 'str'>
# Strongly typed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d65a20bc0116> in <module>
#      67 print(type(num1))
#      68 print('Strongly typed')
# ---> 69 num3=num1 + num2 #strongly typed
#      70 print(num3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Out:
# Conditional Structures
# greatest of 3 numbers
# enter the input1
# 100
# c is greater
